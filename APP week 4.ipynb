# %%
from tkinter import*
from tkinter import ttk

# %%
root=Tk()
root.config(bg='blue')
#creating labels
f_name_label=Label(root,text='FIRST NAME')
l_name_label=Label(root,text='LAST NAME')
DOB_label=Label(root,text='DATE OF BIRTH')
email_label=Label(root,text='EMAIL ID')
m_number_label=Label(root,text='MOBILE NUMBER')
gender_label=Label(root,text='GENDER')
address_label=Label(root,text='ADDRESS')
city_label=Label(root,text='CITY')
pincode_label=Label(root,text='PIN CODE')
state_Label=Label(root,text='STATE')
country_label=Label(root,text='COUNTRY')
hobbies_label=Label(root,text='HOBBIES')
qual_label=Label(root,text='QUALIFICATIONS')
course_label1=Label(root,text='COURSES \n    APPLIED FOR')
max_char_label1=Label(root,text='(max 30 characters a-z and A-Z)')
max_char_label2=Label(root,text='(max 30 characters a-z and A-Z)')
max_char_label3=Label(root,text='(max 30 characters a-z and A-Z)')
max_char_label4=Label(root,text='(max 30 characters a-z and A-Z)')
max_digit_label1=Label(root,text='(10 digit number)')
max_digit_label2=Label(root,text='(6 digit number)')
max_char_label5=Label(root,text='(10 char max)')
max_decimal_label=Label(root,text='(upto 2 decimal)')

#creating the table
slno_label=Label(root,text='Sl.No.Examination')
board_label=Label(root,text='Board')
percentage_label=Label(root,text='Percentage')
yop_label=Label(root,text='Year of Passing')
num1_label=Label(root,text='1')
num2_label=Label(root,text='2')
num3_label=Label(root,text='3')
num4_label=Label(root,text='4')
classx_label=Label(root,text='Class X')
classxii_label=Label(root,text='Class XII')
grad_label=Label(root,text='Graduation')
masters_label=Label(root,text='Masters')

board_entry1=Entry(root)
board_entry2=Entry(root)
board_entry3=Entry(root)
board_entry4=Entry(root)
percentage_entry1=Entry(root)
percentage_entry2=Entry(root)
percentage_entry3=Entry(root)
percentage_entry4=Entry(root)
yop_entry1=Entry(root)
yop_entry2=Entry(root)
yop_entry3=Entry(root)
yop_entry4=Entry(root)

slno_label.grid(row=13,column=1,columnspan=2)
board_label.grid(row=13,column=3)
percentage_label.grid(row=13,column=4)
yop_label.grid(row=13,column=5)
num1_label.grid(row=14,column=1)
classx_label.grid(row=14,column=2)
classxii_label.grid(row=15,column=2)
grad_label.grid(row=16,column=2)
masters_label.grid(row=17,column=2)
num2_label.grid(row=15,column=1)
num3_label.grid(row=16,column=1)
num4_label.grid(row=17,column=1)
classx_label.grid(row=14,column=2)
board_entry1.grid(row=14,column=3)
board_entry2.grid(row=15,column=3)
board_entry3.grid(row=16,column=3)
board_entry4.grid(row=17,column=3)
percentage_entry1.grid(row=14,column=4,padx=10)
percentage_entry2.grid(row=15,column=4,padx=10)
percentage_entry3.grid(row=16,column=4,padx=10)
percentage_entry4.grid(row=17,column=4,padx=10)
yop_entry1.grid(row=14,column=5)
yop_entry2.grid(row=15,column=5)
yop_entry3.grid(row=16,column=5)
yop_entry4.grid(row=17,column=5)
max_char_label5.grid(row=18,column=3)
max_decimal_label.grid(row=18,column=4)

#creating entry
f_name_entry=Entry(root)
l_name_entry=Entry(root)
email_entry=Entry(root)
hobbies_entry=Entry(root)
mob_num_entry=Entry(root)
gender_entry=Entry(root)
address_entry=Entry(root)
city_entry=Entry(root)
state_entry=Entry(root)
pincode_entry=Entry(root)
country_entry=Entry(root)
other_entry=Entry(root)

#creating the menubar
method1 = StringVar(value='Day:') 
daychoosen=ttk.Combobox(root,textvariable=method1)
daychoosen['values']=[item for item in range(1,30)]
method2 = StringVar(value='Month:') 
monthchoosen=ttk.Combobox(root,textvariable=method2)
monthchoosen['values']=['January','February','March','April','May','June','July','August','September','October','November','December']
method3 = StringVar(value='Year:') 
yearchoosen=ttk.Combobox(root,textvariable=method3)
yearchoosen['values']=[item for item in range(1960,2021)]
daychoosen.grid(row=2,column=1,padx=(25,0),pady=10)
monthchoosen.grid(row=2,column=2,padx=(25,0),pady=10)
yearchoosen.grid(row=2,column=3,padx=(25,0),pady=10)

#creating gender radiobutton
r=IntVar()
male=Radiobutton(root,text='Male',variable=r,value=1)
female=Radiobutton(root,text='Female',variable=r,value=2)
male.grid(row=5,column=1,padx=(18,0),pady=10,sticky='W')
female.grid(row=5,column=2,pady=10,sticky='W')
#courses radio button
r1=IntVar()
BCA=Radiobutton(root,text='BCA',variable=r1,value=1)
Bcom=Radiobutton(root,text='B.com',variable=r1,value=2)
BSc=Radiobutton(root,text='B.Sc',variable=r1,value=3)
Ba=Radiobutton(root,text='B.A',variable=r1,value=4)
BCA.grid(row=19,column=1)
Bcom.grid(row=19,column=2)
BSc.grid(row=19,column=3)
Ba.grid(row=19,column=4)

#creating checkbox for hobbies
var=IntVar()
c1=Checkbutton(root, text="Drawing",variable=var, onvalue=1, offvalue=0)
c2=Checkbutton(root, text="Singing",variable=var, onvalue=2, offvalue=0)
c3=Checkbutton(root, text="Dancing",variable=var, onvalue=3, offvalue=0)
c4=Checkbutton(root, text="Sketching",variable=var, onvalue=4, offvalue=0)
c5=Checkbutton(root, text="Others",variable=var, onvalue=5, offvalue=0)
c1.grid(row=11,column=1)
c2.grid(row=11,column=2)
c3.grid(row=11,column=3)
c4.grid(row=11,column=4)
c5.grid(row=12,column=1)
other_entry.grid(row=12,column=2)

#buttons
submit_button=Button(root,text='Submit')
reset_button=Button(root,text='Reset')
submit_button.grid(row=20,column=2)
reset_button.grid(row=20,column=3)

#grid
f_name_label.grid(row=0,column=0)
l_name_label.grid(row=1,column=0)
DOB_label.grid(row=2,column=0)
email_label.grid(row=3,column=0)
m_number_label.grid(row=4,column=0)
gender_label.grid(row=5,column=0)
address_label.grid(row=6,column=0)
city_label.grid(row=7,column=0)
pincode_label.grid(row=8,column=0)
state_Label.grid(row=9,column=0)
country_label.grid(row=10,column=0)
hobbies_label.grid(row=11,column=0)
qual_label.grid(row=13,column=0)
course_label1.grid(row=19,column=0)

f_name_entry.grid(row=0,column=1,padx=(12,0),pady=10)
l_name_entry.grid(row=1,column=1,padx=(12,0),pady=10)
email_entry.grid(row=3,column=1,padx=(12,0),pady=10)
mob_num_entry.grid(row=4,column=1,padx=(12,0),pady=10)
address_entry.grid(row=6,column=1,padx=(12,0),pady=10)
city_entry.grid(row=7,column=1,padx=(12,0),pady=10)
pincode_entry.grid(row=8,column=1,padx=(12,0),pady=10)
state_entry.grid(row=9,column=1,padx=(12,0),pady=10)
country_entry.grid(row=10,column=1,padx=(12,0),pady=10)

max_char_label1.grid(row=0,column=2)
max_char_label2.grid(row=1,column=2)
max_char_label3.grid(row=7,column=2)
max_digit_label1.grid(row=4,column=2,sticky='W')
max_digit_label2.grid(row=8,column=2,sticky='W')
max_char_label4.grid(row=9,column=2)
root.mainloop()
